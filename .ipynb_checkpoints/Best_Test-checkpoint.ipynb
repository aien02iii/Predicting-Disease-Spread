# %% [markdown]
# ## 1.import

# %%
# !pip install statsmodels

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
import math

from __future__ import division
from __future__ import print_function


from sklearn import cross_validation, tree, linear_model,metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV 

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
# from xgboost import XGBRegressor

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

import statsmodels.api as sm

# just for the sake of this blog post!
from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# C:\Users\III\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\III\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## 2.read data

# %%
# 舊寫法
# train_features = pd.read_csv('dengue_features_train.csv')
# train_labels = pd.read_csv('dengue_labels_train.csv')
# 將前三欄變成索引
train_features = pd.read_csv('dengue_features_train.csv',index_col=[0,1,2])
train_labels = pd.read_csv('dengue_labels_train.csv',index_col=[0,1,2])

# %%
train_features
# Out:
#                      week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city year weekofyear
# sj   1990 18              1990-04-30  0.122600  0.103725  0.198483  0.177617
#           19              1990-05-07  0.169900  0.142175  0.162357  0.155486
#           20              1990-05-14  0.032250  0.172967  0.157200  0.170843
#           21              1990-05-21  0.128633  0.245067  0.227557  0.235886
#           22              1990-05-28  0.196200  0.262200  0.251200  0.247340
#           23              1990-06-04       NaN  0.174850  0.254314  0.181743
#           24              1990-06-11  0.112900  0.092800  0.205071  0.210271
#           25              1990-06-18  0.072500  0.072500  0.151471  0.133029
#           26              1990-06-25  0.102450  0.146175  0.125571  0.123600
#           27              1990-07-02       NaN  0.121550  0.160683  0.202567
#           28              1990-07-09  0.192875  0.082350  0.191943  0.152929
#           29              1990-07-16  0.291600  0.211800  0.301200  0.280667
#           30              1990-07-23  0.150567  0.171700  0.226900  0.214557
#           31              1990-07-30       NaN  0.247150  0.379700  0.381357
#           32              1990-08-06       NaN  0.064333  0.164443  0.138857
#           33              1990-08-13       NaN  0.128033  0.206957  0.168243
#           34              1990-08-20  0.190233  0.168800  0.167657  0.172286
#           35              1990-08-27  0.252900  0.330750  0.264171  0.284314
#           36              1990-09-03  0.235400  0.200025  0.283817  0.230443
#           37              1990-09-10  0.127967  0.437100  0.123400  0.148283
#           38              1990-09-17  0.196350  0.182433  0.254829  0.305686
#           39              1990-09-24  0.116100  0.260900  0.199443  0.244217
#           40              1990-10-01  0.228550  0.189750  0.212486  0.201186
#           41              1990-10-08  0.171150  0.067550  0.179467  0.157717
#           42              1990-10-15       NaN  0.070200  0.181617  0.165750
#           43              1990-10-22  0.146200  0.089750  0.128829  0.123929
#           44              1990-10-29  0.252250  0.183433  0.318000  0.295900
#           45              1990-11-05  0.152600  0.181775  0.178329  0.186629
#           46              1990-11-12  0.290800  0.224600  0.180386  0.234886
#           47              1990-11-19  0.272200  0.330350  0.131633  0.125383
# ...                              ...       ...       ...       ...       ...
# iq   2009 49              2009-12-03  0.348529  0.290400  0.410614  0.370457
#           50              2009-12-10  0.192200  0.193529  0.239886  0.285886
#           51              2009-12-17  0.217600  0.240300  0.181771  0.262300
#           52              2009-12-24  0.210422  0.257138  0.221133  0.300256
#      2010 53              2010-01-01       NaN       NaN       NaN       NaN
#           1               2010-01-08  0.124571  0.179129  0.163843  0.135471
#           2               2010-01-15  0.145286  0.142314  0.135300  0.167529
#           3               2010-01-22  0.252114  0.230486  0.187329  0.302786
#           3                               307.8        ...
#           4                               308.3        ...
#           5                               306.1        ...
#           6                               306.2        ...
#           7                               309.2        ...
#           8                               308.2        ...
#           9                               306.3        ...
#           10                              306.9        ...
#           11                              307.4        ...
#           12                              307.9        ...
#           13                              309.1        ...
#           14                              308.4        ...
#           15                              307.3        ...
#           16                              304.7        ...
#           17                              308.4        ...
#           18                              304.7        ...
#           19                              306.0        ...
#           20                              308.7        ...
#           21                              309.7        ...
#           22                              308.5        ...
#           23                              305.5        ...
#           24                              306.1        ...
#           25                              307.8        ...
#
#                       reanalysis_precip_amt_kg_per_m2  \
# city year weekofyear
# sj   1990 18                                    32.00
#           19                                    17.94
#           20                                    26.10
#           21                                    13.90
#           22                                    12.20
#           23                                    26.49
#           24                                    38.60
#           25                                    30.00
#           26                                    37.51
#           27                                    28.40
#           28                                    43.72
#           29                                    40.90
#           30                                    42.53
#           31                                    34.60
#           32                                    20.00
#           33                                   101.90
#           34                                    25.90
#           35                                    39.80
#           36                                    30.40
#           37                                    24.18
#           38                                    36.60
#           39                                    16.40
#           40                                    36.10
#           41                                   132.40
#           42                                   279.60
#           43                                    94.52
#           44                                    22.26
#           45                                    14.40
#           46                                     7.10
#           47                                    36.70
# ...                                               ...
# iq   2009 49                                   134.43
#           50                                    49.32
#           51                                   208.87
#           52                                    66.30
#      2010 53                                      NaN
#           1                                      8.50
#           2                                    144.60
#           3                                     31.20
#           4                                     65.76
#           5                                     95.83
#           6                                    172.70
#           7                                     54.20
#           8                                    288.40
#           9                                    144.98
#           10                                    86.10
#           11                                   191.76
#           12                                   214.90
#           13                                    24.25
#           14                                   164.70
#           15                                   150.80
#           16                                    81.40
#           17                                    23.60
#           18                                    85.46
#           19                                    87.30
#           20                                     8.80
#           21                                    45.00
#           22                                   207.10
#           23                                    50.60
#           24                                    62.33
#           25                                    36.90
#
#                       reanalysis_relative_humidity_percent  \
# city year weekofyear
# sj   1990 18                                     73.365714
#           19                                     77.368571
#           20                                     82.052857
#           21                                     80.337143
#           22                                     80.460000
#           23                                     79.891429
#           24                                     82.000000
#           25                                     83.375714
#           26                                     82.768571
#           27                                     81.281429
#           28                                     81.467143
#           29                                     82.144286
#           30                                     80.742857
#           31                                     80.584286
#           32                                     79.650000
#           33                                     84.178571
#           34                                     80.947143
#           35                                     83.348571
#           36                                     77.172857
#           37                                     81.551429
#           38                                     81.637143
#           39                                     77.048571
#           40                                     78.520000
#           41                                     84.110000
#           42                                     85.621429
#           43                                     85.502857
#           44                                     82.787143
#           45                                     81.715714
#           46                                     75.728571
#           47                                     78.151429
# ...                                                    ...
# iq   2009 49                                     91.708571
#           50                                     87.752857
#           51                                     92.958571
#           52                                     96.885714
#      2010 53                                           NaN
#           1                                      78.271429
#           2                                      89.807143
#           3                                      87.641429
#           4                                      91.798571
#           5                                      90.648571
#           6                                      96.515714
#           7                                      88.365714
#           8                                      94.915714
#           9                                      97.700000
#           10                                     96.250000
#           11                                     96.124286
#           12                                     93.082857
#           13                                     88.707143
#           14                                     95.182857
#           15                                     93.655714
#           8                         10.360000                35.4
#           9                          9.900000                35.4
#           10                        10.050000                35.4
#           11                        12.000000                36.0
#           12                         9.333333                34.5
#           13                        12.300000                35.3
#           14                        12.300000                35.4
#           15                         9.600000                33.0
#           16                         9.600000                33.5
#           17                        12.125000                36.2
#           18                         9.600000                33.2
#           19                        10.400000                33.7
#           20                         9.200000                34.0
#           21                        11.933333                35.4
#           22                        10.500000                34.7
#           23                         6.900000                32.2
#           24                         8.733333                31.2
#           25                         9.900000                33.7
#
#                       station_min_temp_c  station_precip_mm
# city year weekofyear
# sj   1990 18                        20.0               16.0
#           19                        22.2                8.6
#           20                        22.8               41.4
#           21                        23.3                4.0
#           22                        23.9                5.8
#           23                        23.9               39.1
#           24                        23.3               29.7
#           25                        22.8               21.1
#           26                        22.8               21.1
#           27                        24.4                1.1
#           28                        21.7               63.7
#           29                        23.9               12.2
#           30                        22.8               32.6
#           31                        22.8               37.6
#           32                        23.3               11.4
#           33                        22.8               44.7
#           34                        23.3                5.4
#           35                        24.4               13.7
#           36                        23.3               14.2
#           37                        24.4               25.9
#           38                        23.9                3.3
#           39                        24.4               15.8
#           40                        23.9               11.7
#           41                        24.4               57.7
#           42                        23.3               61.8
#           43                        21.7               91.5
#           44                        22.8                6.3
#           45                        23.9                6.6
#           46                        22.2               38.9
#           47                        22.2                9.6
# ...                                  ...                ...
# iq   2009 49                        22.2               49.0
#           50                        21.2               41.9
#           51                        22.0               54.1
#           52                        21.8               31.2
#      2010 53                         NaN                NaN
#           1                         21.8                NaN
#           2                         22.1               15.0
#           3                         22.5                0.8
#           4                         22.4              166.0
#           5                         22.0               62.3
#           6                         22.9               14.5
#           7                         21.4               60.9
#           8                         21.4               29.9
#           9                         21.2                9.9
#           10                        21.4               44.5
#           11                        22.0               22.9
#           12                        21.0               20.0
#           13                        21.0               16.0
#           14                        22.5                NaN
#           15                        21.2               18.0
#           16                        22.5               51.1
#           17                        21.4               35.4
#           18                        21.4                8.1
#           19                        21.2               32.0
#           20                        20.0                2.5
#           21                        22.4               27.0
#           22                        21.7               36.6
#           23                        19.2                7.4
#           24                        21.0               16.0
#           25                        22.2               20.4
#
# [1456 rows x 21 columns]

# %%
print(train_features.shape)  # shape 形狀(列,欄) 
print(train_features.info()) # 描述各項信息 (欄位名稱.有幾筆資料不是空值.資料型態....)
train_features.head()
# Out:
# (1456, 21)
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1456 entries, (sj, 1990, 18) to (iq, 2010, 25)
# Data columns (total 21 columns):
# week_start_date                          1456 non-null object
# ndvi_ne                                  1262 non-null float64
# ndvi_nw                                  1404 non-null float64
# ndvi_se                                  1434 non-null float64
# ndvi_sw                                  1434 non-null float64
# precipitation_amt_mm                     1443 non-null float64
# reanalysis_air_temp_k                    1446 non-null float64
# reanalysis_avg_temp_k                    1446 non-null float64
# reanalysis_dew_point_temp_k              1446 non-null float64
# reanalysis_max_air_temp_k                1446 non-null float64
# reanalysis_min_air_temp_k                1446 non-null float64
# reanalysis_precip_amt_kg_per_m2          1446 non-null float64
# reanalysis_relative_humidity_percent     1446 non-null float64
# reanalysis_sat_precip_amt_mm             1443 non-null float64
# reanalysis_specific_humidity_g_per_kg    1446 non-null float64
# reanalysis_tdtr_k                        1446 non-null float64
# station_avg_temp_c                       1413 non-null float64
# station_diur_temp_rng_c                  1413 non-null float64
# station_max_temp_c                       1436 non-null float64
# station_min_temp_c                       1442 non-null float64
# station_precip_mm                        1434 non-null float64
# dtypes: float64(20), object(1)
# memory usage: 243.9+ KB
# None
#                      week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city year weekofyear
# sj   1990 18              1990-04-30  0.122600  0.103725  0.198483  0.177617
#           19              1990-05-07  0.169900  0.142175  0.162357  0.155486
#           20              1990-05-14  0.032250  0.172967  0.157200  0.170843
#           21              1990-05-21  0.128633  0.245067  0.227557  0.235886
#           22              1990-05-28  0.196200  0.262200  0.251200  0.247340
#
#                       precipitation_amt_mm  reanalysis_air_temp_k  \
# city year weekofyear
# sj   1990 18                         12.42             297.572857
#           19                         22.82             298.211429
#           20                         34.54             298.781429
#           21                         15.36             298.987143
#           22                          7.52             299.518571
#
#                       reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# city year weekofyear
# sj   1990 18                     297.742857                   292.414286
#           19                     298.442857                   293.951429
#           20                     298.878571                   295.434286
#           21                     299.228571                   295.310000
#           22                     299.664286                   295.821429
#
#                       reanalysis_max_air_temp_k        ...          \
# city year weekofyear                                   ...
# sj   1990 18                              299.8        ...
#           19                              300.9        ...
#           20                              300.5        ...
#           21                              301.4        ...
#           22                              301.9        ...
#
#                       reanalysis_precip_amt_kg_per_m2  \
# city year weekofyear
# sj   1990 18                                    32.00
#           19                                    17.94
#           20                                    26.10
#           21                                    13.90
#           22                                    12.20
#
#                       reanalysis_relative_humidity_percent  \
# city year weekofyear
# sj   1990 18                                     73.365714
#           19                                     77.368571
#           20                                     82.052857
#           21                                     80.337143
#           22                                     80.460000
#
#                       reanalysis_sat_precip_amt_mm  \
# city year weekofyear
# sj   1990 18                                 12.42
#           19                                 22.82
#           20                                 34.54
#           21                                 15.36
#           22                                  7.52
#
#                       reanalysis_specific_humidity_g_per_kg  \
# city year weekofyear
# sj   1990 18                                      14.012857
#           19                                      15.372857
#           20                                      16.848571
#           21                                      16.672857
#           22                                      17.210000
#
#                       reanalysis_tdtr_k  station_avg_temp_c  \
# city year weekofyear
# sj   1990 18                   2.628571           25.442857
#           19                   2.371429           26.714286
#           20                   2.300000           26.714286
#           21                   2.428571           27.471429
#           22                   3.014286           28.942857
#
#                       station_diur_temp_rng_c  station_max_temp_c  \
# city year weekofyear
# sj   1990 18                         6.900000                29.4
#           19                         6.371429                31.7
#           20                         6.485714                32.2
#           21                         6.771429                33.3
#           22                         9.371429                35.0
#
#                       station_min_temp_c  station_precip_mm
# city year weekofyear
# sj   1990 18                        20.0               16.0
#           19                        22.2                8.6
#           20                        22.8               41.4
#           21                        23.3                4.0
#           22                        23.9                5.8
#
# [5 rows x 21 columns]

# %%
print(train_labels.shape)    # shape 形狀(列,欄) (1456, 1)
print(train_labels.info())   # info 描述各項信息 (欄位名稱.有幾筆資料不是空值.資料型態....)
train_labels.head()
# Out:
# (1456, 1)
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1456 entries, (sj, 1990, 18) to (iq, 2010, 25)
# Data columns (total 1 columns):
# total_cases    1456 non-null int64
# dtypes: int64(1)
# memory usage: 16.4+ KB
# None
#                       total_cases
# city year weekofyear
# sj   1990 18                    4
#           19                    5
#           20                    4
#           21                    3
#           22                    6

# %% [markdown]
# # 聖胡安(San Juan)
# 位於北美洲加勒比海，為美國自治領地波多黎各的首府和最大城市，該城人口為433,733，是美國管轄的第42大城市。聖胡安是波多黎各最重要的海港以及製造業、金融、文化和旅遊中心。聖胡安都會區的人口約為200萬，占波多黎各全島人口的一半。聖胡安屬於熱帶海洋性氣候，降雨與日照高，雨季在7月至12月。

# %% [markdown]
# ![聖胡安 (波多黎各)](imgs/San_Juan6.jpg)

# %% [markdown]
# # 伊基托斯(Iquitos)
# 位於南美洲，為秘魯亞馬遜叢林地區最大城市，人口約40萬人，為洛雷托大區省會。伊基托斯位於亞馬遜河岸邊，無公路或鐵路與外界連接，對外交通完全依靠航空和亞馬遜河航運。雖然離亞馬遜河河口有3700公里遠，但是小型海輪還是可以溯流而上抵達伊基托斯，使得該地成為世界上距離海岸最遠的海港。

# %% [markdown]
# ![伊基托斯 (秘魯)](imgs/Iquitos.jpg)

# %%
# Seperate data for San Juan
sj_train_features = train_features.loc['sj']   # 只看 聖胡安(San Juan) 城市的資料
sj_train_labels = train_labels.loc['sj']       # 只看 聖胡安(San Juan) 城市的答案

# Separate data for Iquitos
iq_train_features = train_features.loc['iq']   # 只看 伊基托斯(Iquitos) 城市的資料
iq_train_labels = train_labels.loc['iq']       # 只看 伊基托斯(Iquitos) 城市的答案

# %%
print('San Juan')
print('features: ', sj_train_features.shape)  # 聖胡安 有936筆資料
print('labels  : ', sj_train_labels.shape)

print('\nIquitos')
print('features: ', iq_train_features.shape)  # 伊基托斯 有520筆資料
print('labels  : ', iq_train_labels.shape)
# Out:
# San Juan
# features:  (936, 21)
# labels  :  (936, 1)
#
# Iquitos
# features:  (520, 21)
# labels  :  (520, 1)

# %%
sj_train_features
# Out:
#                 week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# year weekofyear
# 1990 18              1990-04-30  0.122600  0.103725  0.198483  0.177617
#      19              1990-05-07  0.169900  0.142175  0.162357  0.155486
#      20              1990-05-14  0.032250  0.172967  0.157200  0.170843
#      21              1990-05-21  0.128633  0.245067  0.227557  0.235886
#      22              1990-05-28  0.196200  0.262200  0.251200  0.247340
#      23              1990-06-04       NaN  0.174850  0.254314  0.181743
#      24              1990-06-11  0.112900  0.092800  0.205071  0.210271
#      25              1990-06-18  0.072500  0.072500  0.151471  0.133029
#      26              1990-06-25  0.102450  0.146175  0.125571  0.123600
#      27              1990-07-02       NaN  0.121550  0.160683  0.202567
#      28              1990-07-09  0.192875  0.082350  0.191943  0.152929
#      29              1990-07-16  0.291600  0.211800  0.301200  0.280667
#      30              1990-07-23  0.150567  0.171700  0.226900  0.214557
#      31              1990-07-30       NaN  0.247150  0.379700  0.381357
#      32              1990-08-06       NaN  0.064333  0.164443  0.138857
#      33              1990-08-13       NaN  0.128033  0.206957  0.168243
#      2                      298.228571                   293.595714
#      3                      297.871429                   293.020000
#      4                      298.128571                   293.635714
#      5                      298.178571                   292.957143
#      6                      297.278571                   291.537143
#      7                      297.907143                   292.941429
#      8                      298.057143                   293.134286
#      9                      298.071429                   292.502857
#      10                     298.007143                   293.052857
#      11                     297.642857                   292.197143
#      12                     297.435714                   292.205714
#      13                     296.957143                   292.095714
#      14                     298.228571                   293.235714
#      15                     297.564286                   292.732857
#      16                     297.778571                   292.274286
#      17                     298.692857                   294.280000
#
#                  reanalysis_max_air_temp_k        ...          \
# year weekofyear                                   ...
# 1990 18                              299.8        ...
#      19                              300.9        ...
#      20                              300.5        ...
#      21                              301.4        ...
#      22                              301.9        ...
#      23                              302.4        ...
#      24                              301.3        ...
#      25                              300.6        ...
#      26                              302.1        ...
#      27                              302.3        ...
#      28                              301.8        ...
#      29                              302.0        ...
#      30                              301.8        ...
#      31                              303.0        ...
#      32                              302.5        ...
#      33                              302.6        ...
#      34                              302.5        ...
#      35                              302.2        ...
#      36                              303.8        ...
#      37                              302.9        ...
#      38                              301.7        ...
#      39                              302.4        ...
#      40                              303.3        ...
#      41                              301.8        ...
#      42                              301.5        ...
#      43                              300.9        ...
#      44                              301.4        ...
#      45                              302.2        ...
#      46                              302.3        ...
#      47                              301.6        ...
# ...                                    ...        ...
# 2007 40                              303.5        ...
#      41                              302.9        ...
#      42                              303.6        ...
#      43                              302.8        ...
#      44                              302.1        ...
#      45                              302.6        ...
#      46                              303.1        ...
#      47                              301.8        ...
#      48                              300.7        ...
#      49                              300.8        ...
#      50                              300.9        ...
#      51                              300.4        ...
#      52                              300.8        ...
# 2008 1                               299.9        ...
#      2                               300.0        ...
#      3                               300.1        ...
#      4                               299.5        ...
#      5                               300.7        ...
#      6                               299.3        ...
#      7                               299.3        ...
#      8                               299.6        ...
#      9                               299.9        ...
#      10                              299.9        ...
#      11                              299.5        ...
#      12                              299.8        ...
#      13                              299.7        ...
#      14                              299.8        ...
#      15                              299.4        ...
#      16                              299.7        ...
#      17                              300.9        ...
#
#                  reanalysis_precip_amt_kg_per_m2  \
# year weekofyear
# 1990 18                                    32.00
#      19                                    17.94
#      20                                    26.10
#      21                                    13.90
#      22                                    12.20
#      23                                    26.49
#      24                                    38.60
#      25                                    30.00
#      26                                    37.51
#      27                                    28.40
#      28                                    43.72
#      29                                    40.90
#      30                                    42.53
#      31                                    34.60
#      32                                    20.00
#      33                                   101.90
#      34                                    25.90
#      35                                    39.80
#      36                                    30.40
#      37                                    24.18
#      38                                    36.60
#      39                                    16.40
#      40                                    36.10
#      41                                   132.40
#      42                                   279.60
#      43                                    94.52
#      44                                    22.26
#      45                                    14.40
#      46                                     7.10
#      47                                    36.70
# ...                                          ...
# 2007 40                                    17.60
#      41                                    21.98
#      42                                     8.30
#      43                                    15.66
#      44                                   174.64
#      45                                    10.30
#      46                                    21.40
#      47                                    43.40
#      48                                     9.78
#      49                                    68.00
#      50                                    66.72
#      51                                    50.53
#      52                                     2.36
# 2008 1                                     27.99
#      2                                     37.66
#      3                                      4.10
#      44                   26.200000                 5.400000
#      45                   27.442857                 6.857143
#      46                   26.814286                 6.685714
#      47                   26.900000                 6.200000
#      48                   25.442857                 5.385714
#      49                   25.842857                 5.400000
#      50                   25.771429                 5.085714
#      51                   25.071429                 4.914286
#      52                   25.085714                 6.242857
# 2008 1                    25.400000                 5.300000
#      2                    24.971429                 5.014286
#      3                    24.428571                 5.628571
#      4                    24.528571                 4.585714
#      5                    24.571429                 6.442857
#      6                    24.214286                 5.157143
#      7                    24.800000                 6.242857
#      8                    24.900000                 5.785714
#      9                    24.742857                 5.500000
#      10                   25.114286                 6.114286
#      11                   25.328571                 5.814286
#      12                   25.200000                 7.042857
#      13                   25.042857                 5.785714
#      14                   26.242857                 6.814286
#      15                   25.000000                 5.714286
#      16                   25.314286                 6.242857
#      17                   27.042857                 7.514286
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm
# year weekofyear
# 1990 18                        29.4                20.0               16.0
#      19                        31.7                22.2                8.6
#      20                        32.2                22.8               41.4
#      21                        33.3                23.3                4.0
#      22                        35.0                23.9                5.8
#      23                        34.4                23.9               39.1
#      24                        32.2                23.3               29.7
#      25                        33.9                22.8               21.1
#      26                        33.9                22.8               21.1
#      27                        33.9                24.4                1.1
#      28                        31.7                21.7               63.7
#      29                        32.8                23.9               12.2
#      30                        31.7                22.8               32.6
#      31                        34.4                22.8               37.6
#      32                        33.3                23.3               11.4
#      33                        32.8                22.8               44.7
#      34                        33.3                23.3                5.4
#      35                        32.2                24.4               13.7
#      36                        32.8                23.3               14.2
#      37                        33.9                24.4               25.9
#      38                        32.8                23.9                3.3
#      39                        32.8                24.4               15.8
#      40                        33.3                23.9               11.7
#      41                        33.3                24.4               57.7
#      42                        32.8                23.3               61.8
#      43                        32.2                21.7               91.5
#      44                        33.3                22.8                6.3
#      45                        33.3                23.9                6.6
#      46                        32.8                22.2               38.9
#      47                        31.7                22.2                9.6
# ...                             ...                 ...                ...
# 2007 40                        32.8                22.2               86.6
#      41                        33.3                23.9               14.5
#      42                        33.9                24.4               10.2
#      43                        32.2                24.4                8.6
#      44                        30.6                22.2               89.2
#      45                        32.2                22.8                4.1
#      46                        31.1                22.8               65.7
#      47                        31.1                22.8               40.4
#      48                        28.9                22.2               36.4
#      49                        29.4                22.8               34.5
#      50                        28.9                22.2               30.2
#      51                        28.9                21.7              108.2
#      52                        28.3                21.1               16.8
# 2008 1                         29.4                22.2               55.5
#      2                         28.3                21.1               64.8
#      3                         27.8                20.6                2.5
#      4                         27.8                21.1               83.1
#      5                         28.9                20.0                3.1
#      6                         27.2                21.1               35.9
#      7                         28.3                21.1                6.4
#      8                         28.3                21.7               13.3
#      9                         27.8                21.1               12.9
#      10                        29.4                21.1               13.0
#      11                        28.9                22.2                4.4
#      12                        30.0                20.6                0.5
#      13                        30.0                21.1                1.8
#      14                        30.6                22.2                0.5
#      15                        29.4                21.7               30.7
#      16                        29.4                21.7               11.2
#      17                        31.7                23.3                0.3
#
# [936 rows x 21 columns]

# %%
# 把年月日刪掉 (1990-04-30)
# Remove `week_start_date` string.
sj_train_features.drop('week_start_date', axis=1, inplace=True)
iq_train_features.drop('week_start_date', axis=1, inplace=True)

# %%
##################### 產生新欄位,上週的資料 ###########################
# 產生'reanalysis_specific_humidity_g_per_kg_before'欄位   (平均露點溫度)
sj_train_features['reanalysis_specific_humidity_g_per_kg_before'] = sj_train_features['reanalysis_specific_humidity_g_per_kg']
sj_train_features.reanalysis_specific_humidity_g_per_kg_before = sj_train_features.reanalysis_specific_humidity_g_per_kg.shift(1)
# print(sj_train_features.reanalysis_specific_humidity_g_per_kg_before)

iq_train_features['reanalysis_specific_humidity_g_per_kg_before'] = iq_train_features['reanalysis_specific_humidity_g_per_kg']
iq_train_features.reanalysis_specific_humidity_g_per_kg_before = iq_train_features.reanalysis_specific_humidity_g_per_kg.shift(1)
# print(iq_train_features.reanalysis_specific_humidity_g_per_kg_before)
#####################################################################################################
# 產生欄位   (平均露點溫度)
sj_train_features['reanalysis_dew_point_temp_k_before'] = sj_train_features['reanalysis_dew_point_temp_k']
sj_train_features.reanalysis_dew_point_temp_k_before = sj_train_features.reanalysis_dew_point_temp_k.shift(1)
iq_train_features['reanalysis_dew_point_temp_k_before'] = iq_train_features['reanalysis_dew_point_temp_k']
iq_train_features.reanalysis_dew_point_temp_k_before = iq_train_features.reanalysis_dew_point_temp_k.shift(1)
#####################################################################################################
# 產生欄位   (最低氣溫)
sj_train_features['reanalysis_min_air_temp_k_before'] = sj_train_features['reanalysis_min_air_temp_k']
sj_train_features.reanalysis_min_air_temp_k_before = sj_train_features.reanalysis_min_air_temp_k.shift(1)
iq_train_features['reanalysis_min_air_temp_k_before'] = iq_train_features['reanalysis_min_air_temp_k']
iq_train_features.reanalysis_min_air_temp_k_before = iq_train_features.reanalysis_min_air_temp_k.shift(1)
#####################################################################################################
# 產生欄位   (最低溫度(測站每日))
sj_train_features['station_min_temp_c_before'] = sj_train_features['station_min_temp_c']
sj_train_features.station_min_temp_c_before = sj_train_features.station_min_temp_c.shift(1)
iq_train_features['station_min_temp_c_before'] = iq_train_features['station_min_temp_c']
iq_train_features.station_min_temp_c_before = iq_train_features.station_min_temp_c.shift(1)
#####################################################################################################
# 產生欄位   (平均溫度(測站每日))
sj_train_features['station_avg_temp_c_before'] = sj_train_features['station_avg_temp_c']
sj_train_features.station_avg_temp_c_before = sj_train_features.station_avg_temp_c.shift(1)
iq_train_features['station_avg_temp_c_before'] = iq_train_features['station_avg_temp_c']
iq_train_features.station_avg_temp_c_before = iq_train_features.station_avg_temp_c.shift(1)
#####################################################################################################
# 產生欄位   (平均氣溫(Mean))
sj_train_features['reanalysis_air_temp_k_before'] = sj_train_features['reanalysis_air_temp_k']
sj_train_features.reanalysis_air_temp_k_before = sj_train_features.reanalysis_air_temp_k.shift(1)
iq_train_features['reanalysis_air_temp_k_before'] = iq_train_features['reanalysis_air_temp_k']
iq_train_features.reanalysis_air_temp_k_before = iq_train_features.reanalysis_air_temp_k.shift(1)
#####################################################################################################
#####################################################################################################
#####################################################################################################
# 產生欄位   (平均露點溫度)
sj_train_features['reanalysis_specific_humidity_g_per_kg_before22'] = sj_train_features['reanalysis_specific_humidity_g_per_kg']
sj_train_features.reanalysis_specific_humidity_g_per_kg_before22 = sj_train_features.reanalysis_specific_humidity_g_per_kg.shift(2)
iq_train_features['reanalysis_specific_humidity_g_per_kg_before22'] = iq_train_features['reanalysis_specific_humidity_g_per_kg']
iq_train_features.reanalysis_specific_humidity_g_per_kg_before22 = iq_train_features.reanalysis_specific_humidity_g_per_kg.shift(2)
#####################################################################################################
# 產生欄位   (平均露點溫度)
sj_train_features['reanalysis_dew_point_temp_k_before22'] = sj_train_features['reanalysis_dew_point_temp_k']
sj_train_features.reanalysis_dew_point_temp_k_before22 = sj_train_features.reanalysis_dew_point_temp_k.shift(2)
iq_train_features['reanalysis_dew_point_temp_k_before22'] = iq_train_features['reanalysis_dew_point_temp_k']
iq_train_features.reanalysis_dew_point_temp_k_before22 = iq_train_features.reanalysis_dew_point_temp_k.shift(2)
#####################################################################################################
# 產生欄位   (最低氣溫)
sj_train_features['reanalysis_min_air_temp_k_before22'] = sj_train_features['reanalysis_min_air_temp_k']
sj_train_features.reanalysis_min_air_temp_k_before22 = sj_train_features.reanalysis_min_air_temp_k.shift(2)
iq_train_features['reanalysis_min_air_temp_k_before22'] = iq_train_features['reanalysis_min_air_temp_k']
iq_train_features.reanalysis_min_air_temp_k_before22 = iq_train_features.reanalysis_min_air_temp_k.shift(2)
#####################################################################################################
# 產生欄位   (最低溫度(測站每日))
sj_train_features['station_min_temp_c_before22'] = sj_train_features['station_min_temp_c']
sj_train_features.station_min_temp_c_before22 = sj_train_features.station_min_temp_c.shift(2)
iq_train_features['station_min_temp_c_before22'] = iq_train_features['station_min_temp_c']
iq_train_features.station_min_temp_c_before22 = iq_train_features.station_min_temp_c.shift(2)
#####################################################################################################
# 產生欄位   (平均溫度(測站每日))
sj_train_features['station_avg_temp_c_before22'] = sj_train_features['station_avg_temp_c']
sj_train_features.station_avg_temp_c_before22 = sj_train_features.station_avg_temp_c.shift(2)
iq_train_features['station_avg_temp_c_before22'] = iq_train_features['station_avg_temp_c']
iq_train_features.station_avg_temp_c_before22 = iq_train_features.station_avg_temp_c.shift(2)
#####################################################################################################
# 產生欄位   (平均氣溫(Mean))
sj_train_features['reanalysis_air_temp_k_before22'] = sj_train_features['reanalysis_air_temp_k']
sj_train_features.reanalysis_air_temp_k_before22 = sj_train_features.reanalysis_air_temp_k.shift(2)
iq_train_features['reanalysis_air_temp_k_before22'] = iq_train_features['reanalysis_air_temp_k']
iq_train_features.reanalysis_air_temp_k_before22 = iq_train_features.reanalysis_air_temp_k.shift(2)

# %%
# Null check# Null  
pd.isnull(sj_train_features).any()    # isnull 查詢 聖胡安各個欄位有無 缺失值
# Out:
# ndvi_ne                                           True
# ndvi_nw                                           True
# ndvi_se                                           True
# ndvi_sw                                           True
# precipitation_amt_mm                              True
# reanalysis_air_temp_k                             True
# reanalysis_avg_temp_k                             True
# reanalysis_dew_point_temp_k                       True
# reanalysis_max_air_temp_k                         True
# reanalysis_min_air_temp_k                         True
# reanalysis_precip_amt_kg_per_m2                   True
# reanalysis_relative_humidity_percent              True
# reanalysis_sat_precip_amt_mm                      True
# reanalysis_specific_humidity_g_per_kg             True
# reanalysis_tdtr_k                                 True
# station_avg_temp_c                                True
# station_diur_temp_rng_c                           True
# station_max_temp_c                                True
# station_min_temp_c                                True
# station_precip_mm                                 True
# reanalysis_specific_humidity_g_per_kg_before      True
# reanalysis_dew_point_temp_k_before                True
# reanalysis_min_air_temp_k_before                  True
# station_min_temp_c_before                         True
# station_avg_temp_c_before                         True
# reanalysis_air_temp_k_before                      True
# reanalysis_specific_humidity_g_per_kg_before22    True
# reanalysis_dew_point_temp_k_before22              True
# reanalysis_min_air_temp_k_before22                True
# station_min_temp_c_before22                       True
# station_avg_temp_c_before22                       True
# reanalysis_air_temp_k_before22                    True
# dtype: bool

# %%
# 聖胡安的訓練資料 . 城市中心東北部的像素 . plot(畫線性圖??) . 直線線寬0.8
(sj_train_features 
     .ndvi_ne
     .plot
     .line(lw=0.8))

plt.title('Vegetation Index over Time')   # 標題 (植被指數隨時間變化)
plt.xlabel('Time')                        # x軸標籤
# Out:
# Text(0.5,0,'Time')

# %%
sj_train_features.fillna(method='ffill', inplace=True)  # fillna 填補缺失值      (ffill:以"前ㄧ個"非NaN的值)
iq_train_features.fillna(method='ffill', inplace=True)

# %% [markdown]
# ### Distribution of labels

# %%
## 練習 var() 方差函數
# print(np.var([9,5,6,8,7])) # 2.0
# print(np.var([1,5,2,3,4])) # 2.0
# print(np.var([3,1,5,7,9])) # 8.0

# %%
print('San Juan')
print('mean: ', sj_train_labels.mean()[0])   # mean 平均值
print('var :', sj_train_labels.var()[0])     # var 方差函數

print('\nIquitos')
print('mean: ', iq_train_labels.mean()[0])
print('var :', iq_train_labels.var()[0])
# Out:
# San Juan
# mean:  34.18055555555556
# var : 2640.045439691045
#
# Iquitos
# mean:  7.565384615384615
# var : 115.8955239365642

# %%
sj_train_labels.hist()                     # hist() 直方圖   (聖胡安的訓練答案)     #######(X 和 y各是什麼??)#######
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C3CCC42B0>]],
#       dtype=object)

# %%
iq_train_labels.hist()                # hist() 直方圖   (伊基托斯的訓練答案)          #######(X 和 y各是什麼??)#######
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C3D058160>]],
#       dtype=object)

# %% [markdown]
# ### Which inputs strongly correlate with total_cases?
# ### 哪些輸入與total_cases強烈相關？

# %%
# 訓練欄位['答案欄位名稱'] = 訓練答案.欄位名稱
sj_train_features['total_cases'] = sj_train_labels.total_cases
iq_train_features['total_cases'] = iq_train_labels.total_cases

# %%
# compute the correlations# comput 
sj_correlations = sj_train_features.corr()   # corr() 計算相關性，不包括NA / null值
iq_correlations = iq_train_features.corr()
# print(sj_correlations)

# %%
# # plot san juan# plot s 
# plt.figure(figsize=(14,8))
# sj_corr_heat = sns.heatmap(sj_correlations)
# plt.title('San Juan Variable Correlations')   # 標題 (聖胡安變量相關)

# %%
# # plot iquitos
# plt.figure(figsize=(14,8))
# iq_corr_heat = sns.heatmap(iq_correlations)
# plt.title('Iquitos Variable Correlations')    # 標題 (伊基托斯變量相關)

# %% [markdown]
# ### Many of the temperature data are strongly correlated, which is expected. But the total_cases variable doesn't have many obvious strong
# ### 許多溫度數據是強相關的，這是預期的。 但是total_cases變量並沒有多明顯的強大

# %%
# San Juan
# sj_correlations = 前面有透過{ sj_train_features.corr() } 計算相關性
(sj_correlations
     .total_cases
     .drop('total_cases')             # don't compare with myself (不要與自己比較)
     .sort_values(ascending=False)    # ascending=False 相關係數由低到高
     .plot
     .barh())

# %%
# Iquitos
(iq_correlations
     .total_cases
     .drop('total_cases') # don't compare with myself
     .sort_values(ascending=False)
     .plot
     .barh())
# 到這邊會發現到 聖胡安 和 伊基托斯 的相關係數還是有一點不同

# %% [markdown]
# ### A mosquito model (蚊子模型)

# %%
def preprocess_data(data_path, labels_path=None):
    # load data and set index to city, year, weekofyear
    df = pd.read_csv(data_path, index_col=[0, 1, 2])
    
    df['reanalysis_specific_humidity_g_per_kg_before'] = df['reanalysis_specific_humidity_g_per_kg']
    df.reanalysis_specific_humidity_g_per_kg_before = df.reanalysis_specific_humidity_g_per_kg.shift(1)
    
    df['reanalysis_dew_point_temp_k_before'] = df['reanalysis_dew_point_temp_k']
    df.reanalysis_dew_point_temp_k_before = df.reanalysis_dew_point_temp_k.shift(1)
    
    df['reanalysis_air_temp_k_before'] = df['reanalysis_air_temp_k']
    df.reanalysis_air_temp_k_before = df.reanalysis_air_temp_k.shift(1)
    
    df['reanalysis_min_air_temp_k_before'] = df['reanalysis_min_air_temp_k']
    df.reanalysis_min_air_temp_k_before = df.reanalysis_min_air_temp_k.shift(1)
    
    df['station_avg_temp_c_before'] = df['station_avg_temp_c']
    df.station_avg_temp_c_before = df.station_avg_temp_c.shift(1)
    
    df['station_min_temp_c_before'] = df['station_min_temp_c']
    df.station_min_temp_c_before = df.station_min_temp_c.shift(1)
######################################################################################################################
    df['reanalysis_specific_humidity_g_per_kg_before22'] = df['reanalysis_specific_humidity_g_per_kg']
    df.reanalysis_specific_humidity_g_per_kg_before22 = df.reanalysis_specific_humidity_g_per_kg.shift(2)
    
    df['reanalysis_dew_point_temp_k_before22'] = df['reanalysis_dew_point_temp_k']
    df.reanalysis_dew_point_temp_k_before22 = df.reanalysis_dew_point_temp_k.shift(2)
    
    df['reanalysis_min_air_temp_k_before22'] = df['reanalysis_min_air_temp_k']
    df.reanalysis_min_air_temp_k_before22 = df.reanalysis_min_air_temp_k.shift(2)
    
    df['station_min_temp_c_before22'] = df['station_min_temp_c']
    df.station_min_temp_c_before22 = df.station_min_temp_c.shift(2)
    
    df['station_avg_temp_c_before22'] = df['station_avg_temp_c']
    df.station_avg_temp_c_before22 = df.station_avg_temp_c.shift(2)
    
    df['reanalysis_air_temp_k_before22'] = df['reanalysis_air_temp_k']
    df.reanalysis_air_temp_k_before22 = df.reanalysis_air_temp_k.shift(2)
    

    
    # select features we want
    features = ['reanalysis_specific_humidity_g_per_kg', 
                 'reanalysis_dew_point_temp_k', 
                 'station_avg_temp_c', 
                 'station_min_temp_c',
                 'reanalysis_specific_humidity_g_per_kg_before',
                 'reanalysis_max_air_temp_k',
                 'reanalysis_min_air_temp_k',
                 'reanalysis_dew_point_temp_k_before',
                 'reanalysis_air_temp_k_before',
                 'station_avg_temp_c_before',
                 'station_min_temp_c_before',
                 'reanalysis_min_air_temp_k_before',
                 'reanalysis_specific_humidity_g_per_kg_before22',
                 'reanalysis_dew_point_temp_k_before22',
                 'reanalysis_min_air_temp_k_before22',
                 'station_min_temp_c_before22',
                 'station_avg_temp_c_before22',
                 'reanalysis_air_temp_k_before22'
               ]
    df = df[features]
    
    # fill missing values
#     df.fillna(method='ffill', inplace=True)
    df.fillna(method='bfill', inplace=True)

    # add labels to dataframe
    if labels_path:
        labels = pd.read_csv(labels_path, index_col=[0, 1, 2])
        df = df.join(labels)
    
    # separate san juan and iquitos
    sj = df.loc['sj']
    iq = df.loc['iq']
    
    return sj, iq

# %%
sj_train, iq_train = preprocess_data('dengue_features_train.csv',labels_path="dengue_labels_train.csv")

# %%
sj_train.describe()
# Out:
#        reanalysis_specific_humidity_g_per_kg  reanalysis_dew_point_temp_k  \
# count                             936.000000                   936.000000
# mean                               16.544976                   295.102279
# std                                 1.560676                     1.569761
# min                                11.715714                   289.642857
# 25%                                15.233571                   293.843929
# 50%                                16.832143                   295.447143
# 75%                                17.854286                   296.415714
# max                                19.440000                   297.795714
#
#        station_avg_temp_c  station_min_temp_c  \
# count          936.000000          936.000000
# mean            26.996688           22.593590
# std              1.417146            1.505427
# min             22.842857           17.800000
# 25%             25.814286           21.700000
# 50%             27.214286           22.800000
# 75%             28.175000           23.900000
# max             30.071429           25.600000
#
#        reanalysis_specific_humidity_g_per_kg_before  \
# count                                    936.000000
# mean                                      16.543204
# std                                        1.562609
# min                                       11.715714
# 25%                                       15.225714
# 50%                                       16.832143
# 75%                                       17.854286
# max                                       19.440000
#
#        reanalysis_max_air_temp_k  reanalysis_min_air_temp_k  \
# count                 936.000000                 936.000000
# mean                  301.389850                 297.296581
# std                     1.260792                   1.292930
# min                   297.800000                 292.600000
# 25%                   300.400000                 296.300000
# 50%                   301.500000                 297.500000
# 75%                   302.400000                 298.400000
# max                   304.300000                 299.900000
#
#        reanalysis_dew_point_temp_k_before  reanalysis_air_temp_k_before  \
# count                          936.000000                    936.000000
# mean                           295.100285                    299.155171
# std                              1.571989                      1.237554
# min                            289.642857                    295.938571
# 25%                            293.832857                    298.180000
# 50%                            295.447143                    299.239286
# 75%                            296.415714                    300.130714
# max                            297.795714                    302.200000
#
#        station_avg_temp_c_before  station_min_temp_c_before  \
# count                 936.000000                 936.000000
# mean                   26.994979                  22.590064
# std                     1.418055                   1.507634
# min                    22.842857                  17.800000
# 25%                    25.810714                  21.700000
# 50%                    27.214286                  22.800000
# 75%                    28.175000                  23.900000
# max                    30.071429                  25.600000
#
#        reanalysis_min_air_temp_k_before  \
# count                        936.000000
# mean                         297.296581
# std                            1.292930
# min                          292.600000
# 25%                          296.300000
# 50%                          297.500000
# 75%                          298.400000
# max                          299.900000
#
#        reanalysis_specific_humidity_g_per_kg_before22  \
# count                                      936.000000
# mean                                        16.543368
# std                                          1.562334
# min                                         11.715714
# 25%                                         15.225714
# 50%                                         16.832143
# 75%                                         17.854286
# max                                         19.440000
#
#        reanalysis_dew_point_temp_k_before22  \
# count                            936.000000
# mean                             295.100435
# std                                1.571726
# min                              289.642857
# 25%                              293.832857
# 50%                              295.447143
# 75%                              296.415714
# max                              297.795714
#
#        reanalysis_min_air_temp_k_before22  station_min_temp_c_before22  \
# count                          936.000000                   936.000000
# mean                           297.296581                    22.588248
# std                              1.292930                     1.509730
# min                            292.600000                    17.800000
# 25%                            296.300000                    21.700000
# 50%                            297.500000                    22.800000
# 75%                            298.400000                    23.900000
# max                            299.900000                    25.600000
#
#        station_avg_temp_c_before22  reanalysis_air_temp_k_before22  \
# count                   936.000000                      936.000000
# mean                     26.995116                      299.155110
# std                       1.417899                        1.237631
# min                      22.842857                      295.938571
# 25%                      25.810714                      298.180000
# 50%                      27.214286                      299.239286
# 75%                      28.175000                      300.130714
# max                      30.071429                      302.200000
#
#        total_cases
# count   936.000000
# mean     34.180556
# std      51.381372
# min       0.000000
# 25%       9.000000
# 50%      19.000000
# 75%      37.000000
# max     461.000000

# %%
sj_train.head()
# Out:
#                  reanalysis_specific_humidity_g_per_kg  \
# year weekofyear
# 1990 18                                      14.012857
#      19                                      15.372857
#      20                                      16.848571
#      21                                      16.672857
#      22                                      17.210000
#
#                  reanalysis_dew_point_temp_k  station_avg_temp_c  \
# year weekofyear
# 1990 18                           292.414286           25.442857
#      19                           293.951429           26.714286
#      20                           295.434286           26.714286
#      21                           295.310000           27.471429
#      22                           295.821429           28.942857
#
#                  station_min_temp_c  \
# year weekofyear
# 1990 18                        20.0
#      19                        22.2
#      20                        22.8
#      21                        23.3
#      22                        23.9
#
#                  reanalysis_specific_humidity_g_per_kg_before  \
# year weekofyear
# 1990 18                                             14.012857
#      19                                             14.012857
#      20                                             15.372857
#      21                                             16.848571
#      22                                             16.672857
#
#                  reanalysis_max_air_temp_k  reanalysis_min_air_temp_k  \
# year weekofyear
# 1990 18                              299.8                      295.9
#      19                              300.9                      296.4
#      20                              300.5                      297.3
#      21                              301.4                      297.0
#      22                              301.9                      297.5
#
#                  reanalysis_dew_point_temp_k_before  \
# year weekofyear
# 1990 18                                  292.414286
#      19                                  292.414286
#      20                                  293.951429
#      21                                  295.434286
#      22                                  295.310000
#
#                  reanalysis_air_temp_k_before  station_avg_temp_c_before  \
# year weekofyear
# 1990 18                            297.572857                  25.442857
#      19                            297.572857                  25.442857
#      20                            298.211429                  26.714286
#      21                            298.781429                  26.714286
#      22                            298.987143                  27.471429
#
#                  station_min_temp_c_before  reanalysis_min_air_temp_k_before  \
# year weekofyear
# 1990 18                               20.0                             295.9
#      19                               20.0                             295.9
#      20                               22.2                             296.4
#      21                               22.8                             297.3
#      22                               23.3                             297.0
#
#                  reanalysis_specific_humidity_g_per_kg_before22  \
# year weekofyear
# 1990 18                                               14.012857
#      19                                               14.012857
#      20                                               14.012857
#      21                                               15.372857
#      22                                               16.848571
#
#                  reanalysis_dew_point_temp_k_before22  \
# year weekofyear
# 1990 18                                    292.414286
#      19                                    292.414286
#      20                                    292.414286
#      21                                    293.951429
#      22                                    295.434286
#
#                  reanalysis_min_air_temp_k_before22  \
# year weekofyear
# 1990 18                                       295.9
#      19                                       295.9
#      20                                       295.9
#      21                                       296.4
#      22                                       297.3
#
#                  station_min_temp_c_before22  station_avg_temp_c_before22  \
# year weekofyear
# 1990 18                                 20.0                    25.442857
#      19                                 20.0                    25.442857
#      20                                 20.0                    25.442857
#      21                                 22.2                    26.714286
#      22                                 22.8                    26.714286
#
#                  reanalysis_air_temp_k_before22  total_cases
# year weekofyear
# 1990 18                              297.572857            4
#      19                              297.572857            5
#      20                              297.572857            4
#      21                              298.211429            3
#      22                              298.781429            6

# %%
iq_train.describe()
# Out:
#        reanalysis_specific_humidity_g_per_kg  reanalysis_dew_point_temp_k  \
# count                             520.000000                   520.000000
# mean                               17.101552                   295.498159
# std                                 1.444031                     1.415423
# min                                12.111429                   290.088571
# 25%                                16.121429                   294.593929
# 50%                                17.435000                   295.862857
# 75%                                18.194643                   296.560000
# max                                20.461429                   298.450000
#
#        station_avg_temp_c  station_min_temp_c  \
# count          520.000000          520.000000
# mean            27.517139           21.200962
# std              0.919522            1.274448
# min             21.400000           14.700000
# 25%             27.000000           20.600000
# 50%             27.570833           21.350000
# 75%             28.085000           22.000000
# max             30.800000           24.200000
#
#        reanalysis_specific_humidity_g_per_kg_before  \
# count                                    520.000000
# mean                                      17.098313
# std                                        1.445349
# min                                       12.111429
# 25%                                       16.102857
# 50%                                       17.435000
# 75%                                       18.194643
# max                                       20.461429
#
#        reanalysis_max_air_temp_k  reanalysis_min_air_temp_k  \
# count                 520.000000                 520.000000
# mean                  307.076538                 292.874231
# std                     2.381323                   1.660301
# min                   300.000000                 286.900000
# 25%                   305.200000                 292.000000
# 50%                   307.050000                 293.100000
# 75%                   308.700000                 294.200000
# max                   314.000000                 296.000000
#
#        reanalysis_dew_point_temp_k_before  reanalysis_air_temp_k_before  \
# count                          520.000000                    520.000000
# mean                           295.495223                    297.872783
# std                              1.416364                      1.168808
# min                            290.088571                    294.635714
# 25%                            294.592857                    297.095357
# 50%                            295.862857                    297.822857
# 75%                            296.560000                    298.655000
# max                            298.450000                    301.637143
#
#        station_avg_temp_c_before  station_min_temp_c_before  \
# count                 520.000000                 520.000000
# mean                   27.516308                  21.203077
# std                     0.919755                   1.277020
# min                    21.400000                  14.700000
# 25%                    27.000000                  20.600000
# 50%                    27.570833                  21.350000
# 75%                    28.085000                  22.000000
# max                    30.800000                  24.200000
#
#        reanalysis_min_air_temp_k_before  \
# count                        520.000000
# mean                         292.881154
# std                            1.665400
# min                          286.900000
# 25%                          292.000000
# 50%                          293.100000
# 75%                          294.200000
# max                          296.000000
#
#        reanalysis_specific_humidity_g_per_kg_before22  \
# count                                      520.000000
# mean                                        17.092626
# std                                          1.452264
# min                                         12.111429
# 25%                                         16.095357
# 50%                                         17.435000
# 75%                                         18.194643
# max                                         20.461429
#
#        reanalysis_dew_point_temp_k_before22  \
# count                            520.000000
# mean                             295.489357
# std                                1.423371
# min                              290.088571
# 25%                              294.586429
# 50%                              295.862857
# 75%                              296.560000
# max                              298.450000
#
#        reanalysis_min_air_temp_k_before22  station_min_temp_c_before22  \
# count                          520.000000                   520.000000
# mean                           292.888846                    21.204423
# std                              1.670090                     1.277175
# min                            286.900000                    14.700000
# 25%                            292.000000                    20.600000
# 50%                            293.100000                    21.400000
# 75%                            294.200000                    22.000000
# max                            296.000000                    24.200000
#
#        station_avg_temp_c_before22  reanalysis_air_temp_k_before22  \
# count                   520.000000                      520.000000
# mean                     27.516079                      297.875253
# std                       0.920289                        1.166931
# min                      21.400000                      294.635714
# 25%                      27.000000                      297.097857
# 50%                      27.570833                      297.822857
# 75%                      28.085000                      298.655000
# max                      30.800000                      301.637143
#
#        total_cases
# count   520.000000
# mean      7.565385
# std      10.765478
# min       0.000000
# 25%       1.000000
# 50%       5.000000
# 75%       9.000000
# max     116.000000

# %% [markdown]
# ### Split it up! (分開)

# %%
sj_train_subtrain = sj_train.head(800)
sj_train_subtest = sj_train.tail(sj_train.shape[0] - 800)

iq_train_subtrain = iq_train.head(400)
iq_train_subtest = iq_train.tail(iq_train.shape[0] - 400)

# %% [markdown]
# ### Training time

# %%
from statsmodels.tools import eval_measures
import statsmodels.formula.api as smf

def get_best_model(train, test):
    # Step 1: specify the form of the model
#     model_formula = "total_cases ~ 1 + " \
#                     "reanalysis_specific_humidity_g_per_kg + " \
#                     "reanalysis_dew_point_temp_k + " \
#                     "station_min_temp_c + " \
#                     "station_avg_temp_c"


    # 目前最好成績25.5385
    model_formula = "total_cases ~ 1 + " \
                    "reanalysis_air_temp_k_before + " \
                    "reanalysis_specific_humidity_g_per_kg + " \
                    "station_min_temp_c_before +" \
                    "reanalysis_min_air_temp_k_before +" \
                    "station_avg_temp_c_before +" \
                    "reanalysis_dew_point_temp_k_before +" \
                    "reanalysis_specific_humidity_g_per_kg_before"




#     # 相關係數前七名
#     model_formula = "total_cases ~ 1 + " \
#                     "reanalysis_air_temp_k_before22 + " \
#                     "reanalysis_specific_humidity_g_per_kg_before + " \
#                     "reanalysis_min_air_temp_k_before22 +" \
#                     "station_min_temp_c_before22 +" \
#                     "reanalysis_dew_point_temp_k_before22 +" \
#                     "station_avg_temp_c_before22 +" \
#                     "reanalysis_specific_humidity_g_per_kg_before22"
                    
#     # 相關係數前四名
#     model_formula = "total_cases ~ 1 + " \
#                     "reanalysis_min_air_temp_k_before +" \
#                     "station_avg_temp_c_before +" \
#                     "reanalysis_dew_point_temp_k_before +" \
#                     "reanalysis_specific_humidity_g_per_kg_before"
             
    
    grid = 10 ** np.arange(-8, -3, dtype=np.float64)
                    
    best_alpha = []
    best_score = 1000
        
    # Step 2: Find the best hyper parameter, alpha
    for alpha in grid:
        model = smf.glm(formula=model_formula,
                        data=train,
                        family=sm.families.NegativeBinomial(alpha=alpha))

        results = model.fit()
        predictions = results.predict(test).astype(int)
        score = eval_measures.meanabs(predictions, test.total_cases)

        if score < best_score:
            best_alpha = alpha
            best_score = score

    print('best alpha = ', best_alpha)
    print('best score = ', best_score)
            
    # Step 3: refit on entire dataset
    full_dataset = pd.concat([train, test])
    model = smf.glm(formula=model_formula,
                    data=full_dataset,
                    family=sm.families.NegativeBinomial(alpha=best_alpha))

    fitted_model = model.fit()
    return fitted_model
########################################################################################################################
def get_best_model2(train, test):
    # Step 1: specify the form of the model
#     model_formula = "total_cases ~ 1 + " \
#                     "reanalysis_specific_humidity_g_per_kg + " \
#                     "reanalysis_dew_point_temp_k + " \
#                     "station_min_temp_c + " \
#                     "station_avg_temp_c"

    # 目前最好成績25.5385
    model_formula = "total_cases ~ 1 + " \
                    "station_min_temp_c + " \
                    "station_min_temp_c_before + " \
                    "reanalysis_min_air_temp_k + " \
                    "reanalysis_dew_point_temp_k_before + " \
                    "reanalysis_specific_humidity_g_per_kg_before +" \
                    "reanalysis_dew_point_temp_k +" \
                    "reanalysis_specific_humidity_g_per_kg"



#     # 相關係數前七名
#     model_formula = "total_cases ~ 1 + " \
#                     "reanalysis_min_air_temp_k + " \
#                     "reanalysis_dew_point_temp_k_before22 + " \
#                     "reanalysis_specific_humidity_g_per_kg_before22 + " \
#                     "reanalysis_dew_point_temp_k_before + " \
#                     "reanalysis_specific_humidity_g_per_kg_before +" \
#                     "reanalysis_dew_point_temp_k +" \
#                     "reanalysis_specific_humidity_g_per_kg"
                    
#     # 相關係數前四名
#     model_formula = "total_cases ~ 1 + " \
#                     "reanalysis_dew_point_temp_k_before + " \
#                     "reanalysis_specific_humidity_g_per_kg_before +" \
#                     "reanalysis_dew_point_temp_k +" \
#                     "reanalysis_specific_humidity_g_per_kg"
                    
                    
    
    grid = 10 ** np.arange(-8, -3, dtype=np.float64)
                    
    best_alpha = []
    best_score = 1000
        
    # Step 2: Find the best hyper parameter, alpha
    for alpha in grid:
        model = smf.glm(formula=model_formula,
                        data=train,
                        family=sm.families.NegativeBinomial(alpha=alpha))

        results = model.fit()
        predictions = results.predict(test).astype(int)
        score = eval_measures.meanabs(predictions, test.total_cases)

        if score < best_score:
            best_alpha = alpha
            best_score = score

    print('best alpha = ', best_alpha)
    print('best score = ', best_score)
            
    # Step 3: refit on entire dataset
    full_dataset = pd.concat([train, test])
    model = smf.glm(formula=model_formula,
                    data=full_dataset,
                    family=sm.families.NegativeBinomial(alpha=best_alpha))

    fitted_model = model.fit()
    return fitted_model
########################################################################################################################
    
sj_best_model = get_best_model(sj_train_subtrain, sj_train_subtest)
iq_best_model = get_best_model2(iq_train_subtrain, iq_train_subtest)
# Out:
# best alpha =  1e-08
# best score =  21.330882352941178
# best alpha =  1e-08
# best score =  6.416666666666667

# %%
figs, axes = plt.subplots(nrows=2, ncols=1)

# plot sj
sj_train['fitted'] = sj_best_model.fittedvalues
sj_train.fitted.plot(ax=axes[0], label="Predictions")
sj_train.total_cases.plot(ax=axes[0], label="Actual")

# plot iq
iq_train['fitted'] = iq_best_model.fittedvalues
iq_train.fitted.plot(ax=axes[1], label="Predictions")
iq_train.total_cases.plot(ax=axes[1], label="Actual")

plt.suptitle("Dengue Predicted Cases vs. Actual Cases")
plt.legend()

# %%
sj_test, iq_test = preprocess_data('dengue_features_test.csv')

sj_predictions = sj_best_model.predict(sj_test).astype(int)
iq_predictions = iq_best_model.predict(iq_test).astype(int)

submission = pd.read_csv("submission_format.csv",
                         index_col=[0, 1, 2])

submission.total_cases = np.concatenate([sj_predictions, iq_predictions])
submission.to_csv("目前最好成績.csv")
